# %%
import numpy as np
import csv
import json
import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.pyplot as plt
import matplotlib.pyplot as mlp
import pandas as pd
from pandas import DataFrame

from sqlalchemy import create_engine

# %%
ATLdf = pd.read_csv('Resources/CSV/United/United - ATL - Detailed Statistics Departures.csv', skiprows=7)[:-2]
ATLdf['Origin_Airport'] = "ATL"
ATLdf = ATLdf.rename(columns={'Destination Airport': 'Destination_Airport'})

Destination_booleans = []
for airport in ATLdf.Destination_Airport:
    if airport == "SFO":
        Destination_booleans.append(True)
    elif airport == "LAX":
        Destination_booleans.append(True)
    elif airport == "DEN":
        Destination_booleans.append(True)
    elif airport == "LAS":
        Destination_booleans.append(True)
    elif airport == "PDX":
        Destination_booleans.append(True)
    elif airport == "SEA":
        Destination_booleans.append(True)
    elif airport == "DFW":
        Destination_booleans.append(True)
    elif airport == "MCO":
        Destination_booleans.append(True)
    elif airport == "ORD":
        Destination_booleans.append(True)
    elif airport == "JFK":
        Destination_booleans.append(True)
    elif airport == "ATL":
        Destination_booleans.append(True)
    else:
        Destination_booleans.append(False)

is_long = pd.Series(Destination_booleans)

ATL_df = ATLdf[is_long]
ATL_df.shape
# Out:
# (9321, 31)

# %%
LAXdf = pd.read_csv('Resources/CSV/United/United - LAX - Detailed Statistics Departures.csv', skiprows=7)[:-2]
LAXdf['Origin_Airport'] = "LAX"
LAXdf = LAXdf.rename(columns={'Destination Airport': 'Destination_Airport'})

Destination_booleans = []
for airport in LAXdf.Destination_Airport:
    if airport == "SFO":
        Destination_booleans.append(True)
    elif airport == "LAX":
        Destination_booleans.append(True)
    elif airport == "DEN":
        Destination_booleans.append(True)
    elif airport == "LAS":
        Destination_booleans.append(True)
    elif airport == "PDX":
        Destination_booleans.append(True)
    elif airport == "SEA":
        Destination_booleans.append(True)
    elif airport == "DFW":
        Destination_booleans.append(True)
    elif airport == "MCO":
        Destination_booleans.append(True)
    elif airport == "ORD":
        Destination_booleans.append(True)
    elif airport == "JFK":
        Destination_booleans.append(True)
    elif airport == "ATL":
        Destination_booleans.append(True)
    else:
        Destination_booleans.append(False)

is_long = pd.Series(Destination_booleans)

LAX_df = LAXdf[is_long]
LAX_df.shape
# Out:
# (60898, 31)

# %%
ORDdf = pd.read_csv('Resources/CSV/United/United - ORD - Detailed Statistics Departures.csv', skiprows=7)[:-2]
ORDdf['Origin_Airport'] = "ORD"
ORDdf = ORDdf.rename(columns={'Destination Airport': 'Destination_Airport'})

Destination_booleans = []
for airport in ORDdf.Destination_Airport:
    if airport == "SFO":
        Destination_booleans.append(True)
    elif airport == "LAX":
        Destination_booleans.append(True)
    elif airport == "DEN":
        Destination_booleans.append(True)
    elif airport == "LAS":
        Destination_booleans.append(True)
    elif airport == "PDX":
        Destination_booleans.append(True)
    elif airport == "SEA":
        Destination_booleans.append(True)
    elif airport == "DFW":
        Destination_booleans.append(True)
    elif airport == "MCO":
        Destination_booleans.append(True)
    elif airport == "ORD":
        Destination_booleans.append(True)
    elif airport == "JFK":
        Destination_booleans.append(True)
    elif airport == "ATL":
        Destination_booleans.append(True)
    else:
        Destination_booleans.append(False)

is_long = pd.Series(Destination_booleans)

ORD_df = ORDdf[is_long]
ORD_df.shape
# Out:
# (101576, 31)

# %%
DFWdf = pd.read_csv('Resources/CSV/United/United - DFW - Detailed Statistics Departures.csv', skiprows=7)[:-2]
DFWdf['Origin_Airport'] = "DFW"
DFWdf = DFWdf.rename(columns={'Destination Airport': 'Destination_Airport'})

Destination_booleans = []
for airport in DFWdf.Destination_Airport:
    if airport == "SFO":
        Destination_booleans.append(True)
    elif airport == "LAX":
        Destination_booleans.append(True)
    elif airport == "DEN":
        Destination_booleans.append(True)
    elif airport == "LAS":
        Destination_booleans.append(True)
    elif airport == "PDX":
        Destination_booleans.append(True)
    elif airport == "SEA":
        Destination_booleans.append(True)
    elif airport == "DFW":
        Destination_booleans.append(True)
    elif airport == "MCO":
        Destination_booleans.append(True)
    elif airport == "ORD":
        Destination_booleans.append(True)
    elif airport == "JFK":
        Destination_booleans.append(True)
    elif airport == "ATL":
        Destination_booleans.append(True)
    else:
        Destination_booleans.append(False)

is_long = pd.Series(Destination_booleans)

DFW_df = DFWdf[is_long]
DFW_df.shape
# Out:
# (15659, 31)

# %%
DENdf = pd.read_csv('Resources/CSV/United/United - DEN - Detailed Statistics Departures.csv', skiprows=7)[:-2]
DENdf['Origin_Airport'] = "DEN"
DENdf = DENdf.rename(columns={'Destination Airport': 'Destination_Airport'})

Destination_booleans = []
for airport in DENdf.Destination_Airport:
    if airport == "SFO":
        Destination_booleans.append(True)
    elif airport == "LAX":
        Destination_booleans.append(True)
    elif airport == "DEN":
        Destination_booleans.append(True)
    elif airport == "LAS":
        Destination_booleans.append(True)
    elif airport == "PDX":
        Destination_booleans.append(True)
    elif airport == "SEA":
        Destination_booleans.append(True)
    elif airport == "DFW":
        Destination_booleans.append(True)
    elif airport == "MCO":
        Destination_booleans.append(True)
    elif airport == "ORD":
        Destination_booleans.append(True)
    elif airport == "JFK":
        Destination_booleans.append(True)
    elif airport == "ATL":
        Destination_booleans.append(True)
    else:
        Destination_booleans.append(False)

is_long = pd.Series(Destination_booleans)

DEN_df = DENdf[is_long]
DEN_df.shape
# Out:
# (86373, 31)

# %%
JFKdf = pd.read_csv('Resources/CSV/United/United - JFK - Detailed Statistics Departures.csv', skiprows=7)[:-2]
JFKdf['Origin_Airport'] = "JFK"
JFKdf = JFKdf.rename(columns={'Destination Airport': 'Destination_Airport'})

Destination_booleans = []
for airport in JFKdf.Destination_Airport:
    if airport == "SFO":
        Destination_booleans.append(True)
    elif airport == "LAX":
        Destination_booleans.append(True)
    elif airport == "DEN":
        Destination_booleans.append(True)
    elif airport == "LAS":
        Destination_booleans.append(True)
    elif airport == "PDX":
        Destination_booleans.append(True)
    elif airport == "SEA":
        Destination_booleans.append(True)
    elif airport == "DFW":
        Destination_booleans.append(True)
    elif airport == "MCO":
        Destination_booleans.append(True)
    elif airport == "ORD":
        Destination_booleans.append(True)
    elif airport == "JFK":
        Destination_booleans.append(True)
    elif airport == "ATL":
        Destination_booleans.append(True)
    else:
        Destination_booleans.append(False)

is_long = pd.Series(Destination_booleans)

JFK_df = JFKdf[is_long]
JFK_df.shape
# Out:
# (3582, 31)

# %%
SFOdf = pd.read_csv('Resources/CSV/United/United - SFO - Detailed Statistics Departures.csv', skiprows=7)[:-2]
SFOdf['Origin_Airport'] = "SFO"
SFOdf = SFOdf.rename(columns={'Destination Airport': 'Destination_Airport'})

Destination_booleans = []
for airport in SFOdf.Destination_Airport:
    if airport == "SFO":
        Destination_booleans.append(True)
    elif airport == "LAX":
        Destination_booleans.append(True)
    elif airport == "DEN":
        Destination_booleans.append(True)
    elif airport == "LAS":
        Destination_booleans.append(True)
    elif airport == "PDX":
        Destination_booleans.append(True)
    elif airport == "SEA":
        Destination_booleans.append(True)
    elif airport == "DFW":
        Destination_booleans.append(True)
    elif airport == "MCO":
        Destination_booleans.append(True)
    elif airport == "ORD":
        Destination_booleans.append(True)
    elif airport == "JFK":
        Destination_booleans.append(True)
    elif airport == "ATL":
        Destination_booleans.append(True)
    else:
        Destination_booleans.append(False)

is_long = pd.Series(Destination_booleans)

SFO_df = SFOdf[is_long]
SFO_df.shape
# Out:
# (111329, 31)

# %%
SEAdf = pd.read_csv('Resources/CSV/United/United - SEA - Detailed Statistics Departures.csv', skiprows=7)[:-2]
SEAdf['Origin_Airport'] = "SEA"
SEAdf = SEAdf.rename(columns={'Destination Airport': 'Destination_Airport'})

Destination_booleans = []
for airport in SEAdf.Destination_Airport:
    if airport == "SFO":
        Destination_booleans.append(True)
    elif airport == "LAX":
        Destination_booleans.append(True)
    elif airport == "DEN":
        Destination_booleans.append(True)
    elif airport == "LAS":
        Destination_booleans.append(True)
    elif airport == "PDX":
        Destination_booleans.append(True)
    elif airport == "SEA":
        Destination_booleans.append(True)
    elif airport == "DFW":
        Destination_booleans.append(True)
    elif airport == "MCO":
        Destination_booleans.append(True)
    elif airport == "ORD":
        Destination_booleans.append(True)
    elif airport == "JFK":
        Destination_booleans.append(True)
    elif airport == "ATL":
        Destination_booleans.append(True)
    else:
        Destination_booleans.append(False)

is_long = pd.Series(Destination_booleans)

SEA_df = SEAdf[is_long]
SEA_df.shape
# Out:
# (28890, 31)

# %%
LASdf = pd.read_csv('Resources/CSV/United/United - LAS - Detailed Statistics Departures.csv', skiprows=7)[:-2]
LASdf['Origin_Airport'] = "LAS"
LASdf = LASdf.rename(columns={'Destination Airport': 'Destination_Airport'})

Destination_booleans = []
for airport in LASdf.Destination_Airport:
    if airport == "SFO":
        Destination_booleans.append(True)
    elif airport == "LAX":
        Destination_booleans.append(True)
    elif airport == "DEN":
        Destination_booleans.append(True)
    elif airport == "LAS":
        Destination_booleans.append(True)
    elif airport == "PDX":
        Destination_booleans.append(True)
    elif airport == "SEA":
        Destination_booleans.append(True)
    elif airport == "DFW":
        Destination_booleans.append(True)
    elif airport == "MCO":
        Destination_booleans.append(True)
    elif airport == "ORD":
        Destination_booleans.append(True)
    elif airport == "JFK":
        Destination_booleans.append(True)
    elif airport == "ATL":
        Destination_booleans.append(True)
    else:
        Destination_booleans.append(False)

is_long = pd.Series(Destination_booleans)

LAS_df = LASdf[is_long]
LAS_df.shape
# Out:
# (36276, 31)

# %%
MCOdf = pd.read_csv('Resources/CSV/United/United - MCO - Detailed Statistics Departures.csv', skiprows=7)[:-2]
MCOdf['Origin_Airport'] = "MCO"
MCOdf = MCOdf.rename(columns={'Destination Airport': 'Destination_Airport'})

Destination_booleans = []
for airport in MCOdf.Destination_Airport:
    if airport == "SFO":
        Destination_booleans.append(True)
    elif airport == "LAX":
        Destination_booleans.append(True)
    elif airport == "DEN":
        Destination_booleans.append(True)
    elif airport == "LAS":
        Destination_booleans.append(True)
    elif airport == "PDX":
        Destination_booleans.append(True)
    elif airport == "SEA":
        Destination_booleans.append(True)
    elif airport == "DFW":
        Destination_booleans.append(True)
    elif airport == "MCO":
        Destination_booleans.append(True)
    elif airport == "ORD":
        Destination_booleans.append(True)
    elif airport == "JFK":
        Destination_booleans.append(True)
    elif airport == "ATL":
        Destination_booleans.append(True)
    else:
        Destination_booleans.append(False)

is_long = pd.Series(Destination_booleans)

MCO_df = MCOdf[is_long]
MCO_df.shape
# Out:
# (23082, 31)

# %%
PDXdf = pd.read_csv('Resources/CSV/United/United - PDX - Detailed Statistics Departures.csv', skiprows=7)[:-2]
PDXdf['Origin_Airport'] = "PDX"
PDXdf = PDXdf.rename(columns={'Destination Airport': 'Destination_Airport'})

Destination_booleans = []
for airport in PDXdf.Destination_Airport:
    if airport == "SFO":
        Destination_booleans.append(True)
    elif airport == "LAX":
        Destination_booleans.append(True)
    elif airport == "DEN":
        Destination_booleans.append(True)
    elif airport == "LAS":
        Destination_booleans.append(True)
    elif airport == "PDX":
        Destination_booleans.append(True)
    elif airport == "SEA":
        Destination_booleans.append(True)
    elif airport == "DFW":
        Destination_booleans.append(True)
    elif airport == "MCO":
        Destination_booleans.append(True)
    elif airport == "ORD":
        Destination_booleans.append(True)
    elif airport == "JFK":
        Destination_booleans.append(True)
    elif airport == "ATL":
        Destination_booleans.append(True)
    else:
        Destination_booleans.append(False)

is_long = pd.Series(Destination_booleans)

PDX_df = PDXdf[is_long]
PDX_df.shape
# Out:
# (24396, 31)

# %%
""" Union all in pandas"""
df_union_all= pd.concat([ATL_df, SFO_df, ORD_df, LAX_df, LAS_df, DFW_df, MCO_df, DEN_df, SEA_df, JFK_df, PDX_df])
df_union_all = df_union_all.set_index('Origin_Airport')
df_union_all = df_union_all.rename(columns={'Carrier Code': 'Carrier_Code'})
df_union_all['Carrier_Code'] = 'United Airlines'
df_union_all = df_union_all.drop(['Unnamed: 17', 'Unnamed: 18','Unnamed: 19', 'Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29'], axis=1)
df_union_all
# Out:
#                    Carrier_Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# Origin_Airport
# ATL             United Airlines          1/1/2015         1746.0      N18223
# ATL             United Airlines          1/1/2016          453.0      N433UA
# ATL             United Airlines          1/1/2016          533.0      N27213
# ATL             United Airlines          1/1/2016         1135.0      N834UA
# ATL             United Airlines          1/1/2016         1900.0      N16234
# ...                         ...               ...            ...         ...
# PDX             United Airlines        12/31/2018         1072.0      N814UA
# PDX             United Airlines        12/31/2018         2004.0      N68817
# PDX             United Airlines        12/31/2018         2054.0      N54241
# PDX             United Airlines        12/31/2018         2223.0      N69838
# PDX             United Airlines        12/31/2018         2233.0      N77538
#
# ...

# %%
export_csv = df_union_all.to_csv('Resources/CSV/Combined/United_Airlines.csv')
