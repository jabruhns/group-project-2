# %%
import os
import pandas as pd

# %%
ATL1 = pd.read_csv("Resources/CSV/American/ATL.csv", skiprows=7)[:-2]
ATL1["Origin Airport"] = "ATL"
ATL1.set_index("Origin Airport")
DEN1 = pd.read_csv("Resources/CSV/American/DEN.csv", skiprows=7)[:-2]
DEN1["Origin Airport"] = "DEN"
DEN1.set_index("Origin Airport")
DFW1 = pd.read_csv("Resources/CSV/American/DFW.csv", skiprows=7)[:-2]
DFW1["Origin Airport"] = "DFW"
DFW1.set_index("Origin Airport")
JFK1 = pd.read_csv("Resources/CSV/American/JFK.csv", skiprows=7)[:-2]
JFK1["Origin Airport"] = "JFK"
JFK1.set_index("Origin Airport")
LAS1 = pd.read_csv("Resources/CSV/American/LAS.csv", skiprows=7)[:-2]
LAS1["Origin Airport"] = "LAS"
LAS1.set_index("Origin Airport")
LAX1 = pd.read_csv("Resources/CSV/American/LAX.csv", skiprows=7)[:-2]
LAX1["Origin Airport"] = "LAX"
LAX1.set_index("Origin Airport")
MCO1 = pd.read_csv("Resources/CSV/American/MCO.csv", skiprows=7)[:-2]
MCO1["Origin Airport"] = "MCO"
MCO1.set_index("Origin Airport")
ORD1 = pd.read_csv("Resources/CSV/American/ORD.csv", skiprows=7)[:-2]
ORD1["Origin Airport"] = "ORD"
ORD1.set_index("Origin Airport")
PDX1 = pd.read_csv("Resources/CSV/American/PDX.csv", skiprows=7)[:-2]
PDX1["Origin Airport"] = "PDX"
PDX1.set_index("Origin Airport")
SEA1 = pd.read_csv("Resources/CSV/American/SEA.csv", skiprows=7)[:-2]
SEA1["Origin Airport"] = "SEA"
SEA1.set_index("Origin Airport")
SFO1 = pd.read_csv("Resources/CSV/American/SFO.csv", skiprows=7)[:-2]
SFO1["Origin Airport"] = "SFO"
SFO1.set_index("Origin Airport")
# Out:
#                Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# Origin Airport
# SFO                      AA        01/01/2015           16.0      N783AA
# SFO                      AA        01/01/2015           20.0      N789AA
# SFO                      AA        01/01/2015           23.0      N371AA
# SFO                      AA        01/01/2015           24.0      N784AA
# SFO                      AA        01/01/2015           68.0      N5EGAA
# ...                     ...               ...            ...         ...
# SFO                      AA        12/31/2018         2533.0      N316PF
# SFO                      AA        12/31/2018         2548.0      N147AA
# SFO                      AA        12/31/2018         2614.0      N990AN
# SFO                      AA        12/31/2018         2634.0      N902AA
# SFO                      AA        12/31/2018         2688.0      N928AM
#
#                Destination Airport Scheduled departure time  \
# Origin Airport
# SFO                            JFK                    12:45
# SFO                            JFK                    15:00
# SFO                            DFW                    10:50
# SFO                            JFK                    07:20
# SFO                            MIA                    07:00
# ...                            ...                      ...
# SFO                            LAX                    12:15
# SFO                            MIA                    21:45
# SFO                            ORD                    07:52
# SFO                            ORD                    14:36
# SFO                            MIA                    22:52
#
#                Actual departure time  Scheduled elapsed time (Minutes)  \
# Origin Airport
# SFO                            13:16                             330.0
# SFO                            15:03                             325.0
# SFO                            11:23                             210.0
# SFO                            07:14                             340.0
# SFO                            07:03                             324.0
# ...                              ...                               ...
# SFO                            12:13                              93.0
# SFO                            21:39                             318.0
# SFO                            07:49                             257.0
# SFO                            14:32                             254.0
# SFO                            22:47                             327.0
#
#                 Actual elapsed time (Minutes)  Departure delay (Minutes)  \
# Origin Airport
# SFO                                     333.0                       31.0
# SFO                                     328.0                        3.0
# SFO                                     217.0                       33.0
# SFO                                     332.0                       -6.0
# SFO                                     317.0                        3.0
# ...                                       ...                        ...
# SFO                                      83.0                       -2.0
# SFO                                     305.0                       -6.0
# SFO                                     255.0                       -3.0
# SFO                                     257.0                       -4.0
# SFO                                     321.0                       -5.0
#
#                Wheels-off time  Taxi-Out time (Minutes)  \
# Origin Airport
# SFO                      13:34                     18.0
# SFO                      15:22                     19.0
# SFO                      11:51                     28.0
# SFO                      07:34                     20.0
# SFO                      07:17                     14.0
# ...                        ...                      ...
# SFO                      12:30                     17.0
# SFO                      21:51                     12.0
# SFO                      08:04                     15.0
# SFO                      14:44                     12.0
# SFO                      23:04                     17.0
#
#                 Delay Carrier (Minutes)  Delay Weather (Minutes)  \
# Origin Airport
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# ...                                 ...                      ...
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
#
#                 Delay National Aviation System (Minutes)  \
# Origin Airport
# SFO                                                  3.0
# SFO                                                  0.0
# SFO                                                  7.0
# SFO                                                  0.0
# SFO                                                  0.0
# ...                                                  ...
# SFO                                                  0.0
# SFO                                                  0.0
# SFO                                                  0.0
# SFO                                                  0.0
# SFO                                                  0.0
#
#                 Delay Security (Minutes)  \
# Origin Airport
# SFO                                  0.0
# SFO                                  0.0
# SFO                                  0.0
# SFO                                  0.0
# SFO                                  0.0
# ...                                  ...
# SFO                                  0.0
# SFO                                  0.0
# SFO                                  0.0
# SFO                                  0.0
# SFO                                  0.0
#
#                 Delay Late Aircraft Arrival (Minutes)
# Origin Airport
# SFO                                              31.0
# SFO                                               0.0
# SFO                                              33.0
# SFO                                               0.0
# SFO                                               0.0
# ...                                               ...
# SFO                                               0.0
# SFO                                               0.0
# SFO                                               0.0
# SFO                                               0.0
# SFO                                               0.0
#
# [68088 rows x 17 columns]

# %%
concat = pd.concat([ATL1, DEN1, DFW1, JFK1, LAS1, LAX1, MCO1, ORD1, PDX1, SEA1, SFO1])
concat['Carrier Code'] = "American Airlines"

# %%
ATL2 = pd.read_csv("Resources/CSV/Alaska/ATL.csv", skiprows=7)[:-2]
ATL2["Origin Airport"] = "ATL"
ATL2.set_index("Origin Airport")
DEN2 = pd.read_csv("Resources/CSV/Alaska/DEN.csv", skiprows=7)[:-2]
DEN2["Origin Airport"] = "DEN"
DEN2.set_index("Origin Airport")
DFW2 = pd.read_csv("Resources/CSV/Alaska/DFW.csv", skiprows=7)[:-2]
DFW2["Origin Airport"] = "DFW"
DFW2.set_index("Origin Airport")
JFK2 = pd.read_csv("Resources/CSV/Alaska/JFK.csv", skiprows=7)[:-2]
JFK2["Origin Airport"] = "JFK"
JFK2.set_index("Origin Airport")
LAS2 = pd.read_csv("Resources/CSV/Alaska/LAS.csv", skiprows=7)[:-2]
LAS2["Origin Airport"] = "LAS"
LAS2.set_index("Origin Airport")
LAX2 = pd.read_csv("Resources/CSV/Alaska/LAX.csv", skiprows=7)[:-2]
LAX2["Origin Airport"] = "LAX"
LAX2.set_index("Origin Airport")
MCO2 = pd.read_csv("Resources/CSV/Alaska/MCO.csv", skiprows=7)[:-2]
MCO2["Origin Airport"] = "MCO"
MCO2.set_index("Origin Airport")
ORD2 = pd.read_csv("Resources/CSV/Alaska/ORD.csv", skiprows=7)[:-2]
ORD2["Origin Airport"] = "ORD"
ORD2.set_index("Origin Airport")
PDX2 = pd.read_csv("Resources/CSV/Alaska/PDX.csv", skiprows=7)[:-2]
PDX2["Origin Airport"] = "PDX"
PDX2.set_index("Origin Airport")
SEA2 = pd.read_csv("Resources/CSV/Alaska/SEA.csv", skiprows=7)[:-2]
SEA2["Origin Airport"] = "SEA"
SEA2.set_index("Origin Airport")
SFO2 = pd.read_csv("Resources/CSV/Alaska/SFO.csv", skiprows=7)[:-2]
SFO2["Origin Airport"] = "SFO"
SFO2.set_index("Origin Airport")
# Out:
#                Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# Origin Airport
# SFO                      AS        01/01/2015          223.0      N315AS
# SFO                      AS        01/01/2015          235.0      N319AS
# SFO                      AS        01/01/2015          303.0      N797AS
# SFO                      AS        01/01/2015          305.0      N453AS
# SFO                      AS        01/01/2015          306.0      N795AS
# ...                     ...               ...            ...         ...
# SFO                      AS        12/31/2018         1952.0      N521VA
# SFO                      AS        12/31/2018         1954.0      N629VA
# SFO                      AS        12/31/2018         1960.0      N362VA
# SFO                      AS        12/31/2018         1964.0      N527VA
# SFO                      AS        12/31/2018         1968.0      N363VA
#
#                Destination Airport Scheduled departure time  \
# Origin Airport
# SFO                            SEA                    20:45
# SFO                            PDX                    20:30
# SFO                            SEA                    10:10
# SFO                            SEA                    13:00
# SFO                            PSP                    14:50
# ...                            ...                      ...
# SFO                            SAN                    09:10
# SFO                            SAN                    12:00
# SFO                            SAN                    18:55
# SFO                            SAN                    21:15
# SFO                            SAN                    15:45
#
#                Actual departure time  Scheduled elapsed time (Minutes)  \
# Origin Airport
# SFO                            21:21                             116.0
# SFO                            20:37                              99.0
# SFO                            10:10                             122.0
# SFO                            13:01                             123.0
# SFO                            16:21                              84.0
# ...                              ...                               ...
# SFO                            08:56                              98.0
# SFO                            11:58                              97.0
# SFO                            00:00                              94.0
# SFO                            21:10                              94.0
# SFO                            15:44                              94.0
#
#                 Actual elapsed time (Minutes)  Departure delay (Minutes)  \
# Origin Airport
# SFO                                     129.0                       36.0
# SFO                                     101.0                        7.0
# SFO                                     119.0                        0.0
# SFO                                     118.0                        1.0
# SFO                                      86.0                       91.0
# ...                                       ...                        ...
# SFO                                      97.0                      -14.0
# SFO                                      83.0                       -2.0
# SFO                                       0.0                        0.0
# SFO                                      83.0                       -5.0
# SFO                                      75.0                       -1.0
#
#                Wheels-off time  Taxi-Out time (Minutes)  \
# Origin Airport
# SFO                      21:46                     25.0
# SFO                      20:53                     16.0
# SFO                      10:26                     16.0
# SFO                      13:20                     19.0
# SFO                      16:33                     12.0
# ...                        ...                      ...
# SFO                      09:22                     26.0
# SFO                      12:15                     17.0
# SFO                      00:00                      0.0
# SFO                      21:25                     15.0
# SFO                      15:54                     10.0
#
#                 Delay Carrier (Minutes)  Delay Weather (Minutes)  \
# Origin Airport
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# ...                                 ...                      ...
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
# SFO                                 0.0                      0.0
#
#                 Delay National Aviation System (Minutes)  \
# Origin Airport
# SFO                                                 13.0
# SFO                                                  0.0
# SFO                                                  0.0
# SFO                                                  0.0
# SFO                                                  2.0
# ...                                                  ...
# SFO                                                  0.0
# SFO                                                  0.0
# SFO                                                  0.0
# SFO                                                  0.0
# SFO                                                  0.0
#
#                 Delay Security (Minutes)  \
# Origin Airport
# SFO                                  0.0
# SFO                                  0.0
# SFO                                  0.0
# SFO                                  0.0
# SFO                                  0.0
# ...                                  ...
# SFO                                  0.0
# SFO                                  0.0
# SFO                                  0.0
# SFO                                  0.0
# SFO                                  0.0
#
#                 Delay Late Aircraft Arrival (Minutes)
# Origin Airport
# SFO                                              36.0
# SFO                                               0.0
# SFO                                               0.0
# SFO                                               0.0
# SFO                                              91.0
# ...                                               ...
# SFO                                               0.0
# SFO                                               0.0
# SFO                                               0.0
# SFO                                               0.0
# SFO                                               0.0
#
# [57615 rows x 17 columns]

# %%
concat = pd.concat([ATL1,])
